# %% [markdown]
# # MATH 210 Introduction to Mathematical Computing
#
# **April 8, 2026**

# %%
import numpy as np
import scipy.linalg as la

# %%
A = np.array([[1.,2.],[2.,1.]])
print(A)
# Out:
# [[1. 2.]
#  [2. 1.]]

# %%
D,P = la.eig(A)

# %%
D
# Out:
# array([ 3.+0.j, -1.+0.j])

# %%
np.real(D)
# Out:
# array([ 3., -1.])

# %%
P
# Out:
# array([[ 0.70710678, -0.70710678],
#        [ 0.70710678,  0.70710678]])

# %%
1/2**0.5
# Out:
# 0.7071067811865475

# %%
D = np.diag(D.real)
D
# Out:
# array([[ 3.,  0.],
#        [ 0., -1.]])

# %%
P @ D @ la.inv(P)
# Out:
# array([[1., 2.],
#        [2., 1.]])

# %%
A @ A @ A @ A @ A
# Out:
# array([[121., 122.],
#        [122., 121.]])

# %%
P @ np.diag([3**5,(-1)**5]) @ la.inv(P)
# Out:
# array([[121., 122.],
#        [122., 121.]])
